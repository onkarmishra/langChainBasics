# %%
import os
import openai
import sys
sys.path.append('../..')

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.environ['OPENAI_API_KEY']

# %%
from langchain.document_loaders import PyPDFLoader
loader = PyPDFLoader("docs/cs229_lectures/MachineLearning-Lecture01.pdf")
pages = loader.load()

# %%
len(pages)
# Out:
# 22

# %%
page = pages[0]

# %%
print(page.page_content[0:500])
# Out:
# MachineLearning-Lecture01
# Instructor (Andrew Ng):  Okay. Good morning. Welcome to CS229, the machine
# learning class. So what I wanna do today is ju st spend a little time going over the logistics
# of the class, and then we'll start to  talk a bit about machine learning.
# By way of introduction, my name's  Andrew Ng and I'll be instru ctor for this class. And so
# I personally work in machine learning, and I' ve worked on it for about 15 years now, and
# I actually think that machine learning i

# %%
page.metadata
# Out:
# {'source': 'docs/cs229_lectures/MachineLearning-Lecture01.pdf', 'page': 0}

# %% [markdown]
# ### YouTube

# %%
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

# %%
url="https://www.youtube.com/watch?v=jGwO_UgTS7I"
save_dir="docs/youtube/"
loader = GenericLoader(
    YoutubeAudioLoader([url],save_dir),
    OpenAIWhisperParser()
)
docs = loader.load()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jGwO_UgTS7I
# [youtube] jGwO_UgTS7I: Downloading webpage
# [youtube] jGwO_UgTS7I: Downloading ios player API JSON
# [youtube] jGwO_UgTS7I: Downloading android player API JSON
# [youtube] jGwO_UgTS7I: Downloading m3u8 information
# [info] jGwO_UgTS7I: Downloading 1 format(s): 140
# [download] docs/youtube//Stanford CS229： Machine Learning Course, Lecture 1 - Andrew Ng (Autumn 2018).m4a has already been downloaded
# [download] 100% of   69.71MiB
# ERROR: Postprocessing: ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location
# ---------------------------------------------------------------------------
# PostProcessingError                       Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:3439, in YoutubeDL.process_info(self, info_dict)
#    3438 try:
# -> 3439     replace_info_dict(self.post_process(dl_filename, info_dict, files_to_move))
#    3440 except PostProcessingError as err:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:3621, in YoutubeDL.post_process(self, filename, info, files_to_move)
#    3620 info['__files_to_move'] = files_to_move or {}
# -> 3621 info = self.run_all_pps('post_process', info, additional_pps=info.get('__postprocessors'))
#    3622 info = self.run_pp(MoveFilesAfterDownloadPP(self), info)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:3603, in YoutubeDL.run_all_pps(self, key, info, additional_pps)
#    3602 for pp in (additional_pps or []) + self._pps[key]:
# -> 3603     info = self.run_pp(pp, info)
#    3604 return info
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:3581, in YoutubeDL.run_pp(self, pp, infodict)
#    3580 try:
# -> 3581     files_to_delete, infodict = pp.run(infodict)
#    3582 except PostProcessingError as e:
#    3583     # Must be True and not 'only_download'
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/postprocessor/common.py:24, in PostProcessorMetaClass.run_wrapper.<locals>.run(self, info, *args, **kwargs)
#      23 self._hook_progress({'status': 'started'}, info_copy)
# ---> 24 ret = func(self, info, *args, **kwargs)
#      25 if ret is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/postprocessor/common.py:129, in PostProcessor._restrict_to.<locals>.decorator.<locals>.wrapper(self, info)
#     128 if allowed[format_type]:
# --> 129     return func(self, info)
#     130 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/postprocessor/ffmpeg.py:493, in FFmpegExtractAudioPP.run(self, information)
#     491     return [], information
# --> 493 filecodec = self.get_audio_codec(path)
#     494 if filecodec is None:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/postprocessor/ffmpeg.py:241, in FFmpegPostProcessor.get_audio_codec(self, path)
#     240 if not self.probe_available and not self.available:
# --> 241     raise PostProcessingError('ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location')
#     242 try:
#
# PostProcessingError: ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# Cell In[9], line 7
#       2 save_dir="docs/youtube/"
#       3 loader = GenericLoader(
#       4     YoutubeAudioLoader([url],save_dir),
#       5     OpenAIWhisperParser()
#       6 )
# ----> 7 docs = loader.load()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/langchain/document_loaders/generic.py:90, in GenericLoader.load(self)
#      88 def load(self) -> List[Document]:
#      89     """Load all documents."""
# ---> 90     return list(self.lazy_load())
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/langchain/document_loaders/generic.py:85, in GenericLoader.lazy_load(self)
#      81 def lazy_load(
#      82     self,
#      83 ) -> Iterator[Document]:
#      84     """Load documents lazily. Use this when working at a large scale."""
# ---> 85     for blob in self.blob_loader.yield_blobs():
#      86         yield from self.blob_parser.lazy_parse(blob)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/langchain/document_loaders/blob_loaders/youtube_audio.py:45, in YoutubeAudioLoader.yield_blobs(self)
#      42 for url in self.urls:
#      43     # Download file
#      44     with yt_dlp.YoutubeDL(ydl_opts) as ydl:
# ---> 45         ydl.download(url)
#      47 # Yield the written blobs
#      48 loader = FileSystemBlobLoader(self.save_dir, glob="*.m4a")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:3485, in YoutubeDL.download(self, url_list)
#    3482     raise SameFileError(outtmpl)
#    3484 for url in url_list:
# -> 3485     self.__download_wrapper(self.extract_info)(
#    3486         url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    3488 return self._download_retcode
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:3460, in YoutubeDL.__download_wrapper.<locals>.wrapper(*args, **kwargs)
#    3457 @functools.wraps(func)
#    3458 def wrapper(*args, **kwargs):
#    3459     try:
# -> 3460         res = func(*args, **kwargs)
#    3461     except UnavailableVideoError as e:
#    3462         self.report_error(e)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:1549, in YoutubeDL.extract_info(self, url, download, ie_key, extra_info, process, force_generic_extractor)
#    1547             raise ExistingVideoReached()
#    1548         break
# -> 1549     return self.__extract_info(url, self.get_info_extractor(key), download, extra_info, process)
#    1550 else:
#    1551     extractors_restricted = self.params.get('allowed_extractors') not in (None, ['default'])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:1560, in YoutubeDL._handle_extraction_exceptions.<locals>.wrapper(self, *args, **kwargs)
#    1558 while True:
#    1559     try:
# -> 1560         return func(self, *args, **kwargs)
#    1561     except (DownloadCancelled, LazyList.IndexError, PagedList.IndexError):
#    1562         raise
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:1709, in YoutubeDL.__extract_info(self, url, ie, download, extra_info, process)
#    1707 if process:
#    1708     self._wait_for_video(ie_result)
# -> 1709     return self.process_ie_result(ie_result, download, extra_info)
#    1710 else:
#    1711     return ie_result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:1768, in YoutubeDL.process_ie_result(self, ie_result, download, extra_info)
#    1766 if result_type == 'video':
#    1767     self.add_extra_info(ie_result, extra_info)
# -> 1768     ie_result = self.process_video_result(ie_result, download=download)
#    1769     self._raise_pending_errors(ie_result)
#    1770     additional_urls = (ie_result or {}).get('additional_urls')
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:2897, in YoutubeDL.process_video_result(self, info_dict, download)
#    2895 downloaded_formats.append(new_info)
#    2896 try:
# -> 2897     self.process_info(new_info)
#    2898 except MaxDownloadsReached:
#    2899     max_downloads_reached = True
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:3441, in YoutubeDL.process_info(self, info_dict)
#    3439     replace_info_dict(self.post_process(dl_filename, info_dict, files_to_move))
#    3440 except PostProcessingError as err:
# -> 3441     self.report_error('Postprocessing: %s' % str(err))
#    3442     return
#    3443 try:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:1042, in YoutubeDL.report_error(self, message, *args, **kwargs)
#    1037 def report_error(self, message, *args, **kwargs):
#    1038     '''
#    1039     Do the same as trouble, but prefixes the message with 'ERROR:', colored
#    1040     in red if stderr is a tty file.
#    1041     '''
# -> 1042     self.trouble(f'{self._format_err("ERROR:", self.Styles.ERROR)} {message}', *args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/openai/lib/python3.9/site-packages/yt_dlp/YoutubeDL.py:981, in YoutubeDL.trouble(self, message, tb, is_error)
#     979     else:
#     980         exc_info = sys.exc_info()
# --> 981     raise DownloadError(message, exc_info)
#     982 self._download_retcode = 1
#
# DownloadError: ERROR: Postprocessing: ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location
